# %%
import sqlalchemy as sa
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = sa.create_engine('postgresql://localhost:5432/group_2_project_3')
connection = engine.connect()

# %%
parks_df = pd.read_sql_table('parks', engine)
parks_df
# Out:
#                                                   park  latitude  longitude  \
# 0                                        Miners Castle       NaN        NaN
# 1                          Green River Bluffs Overlook      37.0      -86.0
# 2                          Elizabeth Eckford Bus Bench       NaN        NaN
# 3    South Junction of Front Curvilinear Sidewalks ...       NaN        NaN
# 4    North Curvilinear Front Sidewalk at Central Hi...       NaN        NaN
# ..                                                 ...       ...        ...
# 891                      Empire Bluff Trail - Old Logs      45.0      -86.0
# 892                   Empire Bluff Trail - The Ice Age      45.0      -86.0
# 893                                   Old Mastic House      41.0      -73.0
# 894                             Signs: Blacksmith Shop      34.0     -120.0
# 895                                       River Raisin      42.0      -83.0
#
#                                                    url  \
# 0         https://www.nps.gov/places/miners-castle.htm
# 1    https://www.nps.gov/places/green-river-bluffs-...
# 2    https://www.nps.gov/places/elizabeth-eckford-b...
# 3    https://www.nps.gov/places/south-junction-of-f...
# 4    https://www.nps.gov/places/north-curvilinear-f...
# ..                                                 ...
# 891  https://www.nps.gov/places/000/empire-bluff-tr...
# 892  https://www.nps.gov/places/000/empire-bluff-tr...
# 893    https://www.nps.gov/places/old-mastic-house.htm
# 894  https://www.nps.gov/places/signs-blacksmith-sh...
# 895          https://www.nps.gov/places/frenchtown.htm
#
#                                   park_id park_code  \
# 0    A17C6BB6-FE40-42EC-ACB8-EF5A6BE3DA7E      piro
# 1    D3531106-B29D-442D-94F3-B01DF70EAC40      maca
# 2    CB66E326-BC14-4E81-A6A3-EF7A2D874FAB      chsc
# 3    5760ED27-E5DA-47C5-A76F-1F83FB769267      chsc
# 4    6CA3DA56-4062-4848-B49F-D9C66F377D13      chsc
# ..                                    ...       ...
# 891  D9385C45-B3FD-4000-85DF-7436BFF75DD9      slbe
# 892  93DC0589-85AD-4C6E-89F0-3A577F599AFE      slbe
# 893  2B7ECA11-6C0F-4E52-8497-823A287B8E4A      fiis
# 894  06FC0EFF-9562-4E51-AACC-6BC1D5612454      chis
# 895  CF90DD80-3730-4306-B3BD-295DEF1B85D9      rira
#
#                      park_type  \
# 0           National Lakeshore
# 1                National Park
# 2       National Historic Site
# 3       National Historic Site
# 4       National Historic Site
# ..                         ...
# 891         National Lakeshore
# 892         National Lakeshore
# 893          National Seashore
# 894              National Park
# 895  National Battlefield Park
#
#                                                  image state  \
# 0    https://www.nps.gov/common/uploads/cropped_ima...    MI
# 1    https://www.nps.gov/common/uploads/cropped_ima...    KY
# 2    https://www.nps.gov/common/uploads/cropped_ima...    AR
# 3    https://www.nps.gov/common/uploads/cropped_ima...    AR
# 4    https://www.nps.gov/common/uploads/cropped_ima...    AR
# ..                                                 ...   ...
# 891  https://www.nps.gov/common/uploads/cropped_ima...    MI
# 892  https://www.nps.gov/common/uploads/cropped_ima...    MI
# 893  https://www.nps.gov/common/uploads/cropped_ima...    NY
# 894  https://www.nps.gov/common/uploads/cropped_ima...    CA
# 895  https://www.nps.gov/common/uploads/cropped_ima...    MI
#
#                                       coord
# 0
# 1      37.19327420021557,-86.10334360000695
# 2
# 3
# 4
# ..                                      ...
# 891                    44.801479,-86.069491
# 892                    44.799515,-86.059685
# 893                    40.773316,-72.829827
# 894  34.049057581208245,-119.55813265275955
# 895     41.91090905876359,-83.3788222892991
#
# [896 rows x 10 columns]

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['webcams', 'parks']
